# %%
## 1)Draw Scatter Plot between SepalLengthCm and SepalWidthCm for “Iris.csv” file with proper labelling.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/1.sem6/ML/MachineLearning/CE032_Lab1/iris.csv")

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
x=df["sepal.length"]

# %%
y=df['sepal.width']

# %%
plt.scatter(x,y,color="red")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
##2) Draw Histogram of SepalLengthCm with proper labelling.
plt.hist(x,bins=10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
##4) Count total null values for each column in this dataset.
print(df.isnull().sum())
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df[["sepal.length"]].iloc[1:6,:]
# Out:
#    sepal.length
# 1           4.9
# 2           4.7
# 3           4.6
# 4           5.0
# 5           5.4

# %%
##5) i) Print first 5 rows of SepalLengthCm. ii) Print from 5th row and onwards and entire columnof Iris.csv dataset.
df.iloc[5:,:]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [145 rows x 5 columns]

# %%
##3) Plot bar chart of Species.
import seaborn as sms

# %%
sms.countplot("variety",data=df)
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')
